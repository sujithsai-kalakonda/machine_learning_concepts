# %% [markdown]
# # **Pandas Case Study - Indian Startup Funding**

# %%
import pandas as pd

# %%
# load startup_funding.csv
df = pd.read_csv('startup_funding.csv')
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# 1  Susquehanna Growth Equity              Series C     80,48,394     NaN
# 2      Sequoia Capital India              Series B   1,83,58,860     NaN
# 3             Vinod Khatumal          Pre-series A     30,00,000     NaN
# 4    Sprout Venture Partners            Seed Round     18,00,000     NaN

# %%
df.sample(5)
# Out:
#       Sr No Date dd/mm/yyyy  Startup Name               Industry Vertical  \
# 2131   2132      07/12/2015     Coolshare  Cab Sharing service Mobile app
# 1056   1057      10/01/2017    DriveSkool               Consumer Internet
# 3013   3014      18/01/2015     ShopClues                             NaN
# 139     140      22/11/2018      Skillbox                  Social Network
# 2851   2852      23/04/2015  Craftstvilla        Ethnic Product eCommerce
#
#                                  SubVertical City  Location  \
# 2131                                     NaN         Mumbai
# 1056  online marketplace for driving schools      Bangalore
# 3013                                     NaN            NaN
# 139                                      Art       Gurugram
# 2851                                     NaN         Mumbai
#
#                                          Investors Name InvestmentnType  \
# 2131                                     Gopal Aggarwal    Seed Funding
# 1056                                     Aavya Ventures    Seed Funding
# 3013                     Tiger Global & Other investors  Private Equity
# 139                                Individual investors    Seed Funding
# 2851  Sequoia Capital, Nexus venture Partners, Light...  Private Equity
#
#      Amount in USD       Remarks
# 2131      1,00,000           NaN
# 1056           NaN           NaN
# 3013  10,00,00,000  More Details
# 139    Undisclosed           NaN
# 2851   1,80,00,000      Series B

# %%
df.shape
# Out:
# (3044, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
# We can observe here there are many "NaN" values and 
# the data provided is not very clean to start the analysis

# %% [markdown]
# ## ``Preprocessing``

# %% [markdown]
# * 1. Make `Sr No` as index

# %%
df.drop(columns=['Remarks'], inplace=True)

# %%
df.head(3)
# Out:
#    Sr No Date dd/mm/yyyy Startup Name Industry Vertical  \
# 0      1      09/01/2020       BYJU’S            E-Tech
# 1      2      13/01/2020       Shuttl    Transportation
# 2      3      09/01/2020    Mamaearth        E-commerce
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
#
#               Investors Name       InvestmentnType Amount in USD
# 0    Tiger Global Management  Private Equity Round  20,00,00,000
# 1  Susquehanna Growth Equity              Series C     80,48,394
# 2      Sequoia Capital India              Series B   1,83,58,860

# %% [markdown]
# * 2. `Drop remarks col` --> contains only 419 non-null values out of 3044

# %%
df.set_index('Sr No', inplace=True)

# %%
df.head(2)
# Out:
#       Date dd/mm/yyyy Startup Name Industry Vertical  \
# Sr No
# 1          09/01/2020       BYJU’S            E-Tech
# 2          13/01/2020       Shuttl    Transportation
#
#                      SubVertical City  Location             Investors Name  \
# Sr No
# 1                     E-learning      Bengaluru    Tiger Global Management
# 2      App based shuttle service        Gurgaon  Susquehanna Growth Equity
#
#             InvestmentnType Amount in USD
# Sr No
# 1      Private Equity Round  20,00,00,000
# 2                  Series C     80,48,394
